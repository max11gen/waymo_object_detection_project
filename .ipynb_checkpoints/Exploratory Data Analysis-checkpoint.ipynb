# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from os import walk
from os.path import isfile, join
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.patches import Rectangle
from PIL import Image
import tensorflow.compat.v1 as tf
import numpy as np

from utils import get_dataset

# %%
dataset = get_dataset("./data/waymo/training_and_validation/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord")
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['./data/waymo/training_and_validation/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['./data/waymo/training_and_validation/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_instances` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_instances(batch):
    """
    This function takes a batch from the dataset and display the image with 
    the associated bounding boxes.
    """
    colormap = {1: [1, 0, 0], 2: [0, 1, 0], 4: [0, 0, 1]}
    image=batch['image'].numpy()
    img_shape=image.shape
    gt_boxes=batch['groundtruth_boxes'].numpy()
    gt_classes=batch['groundtruth_classes'].numpy()
    f,ax=plt.subplots()
    ax.imshow(image)
    for gt_box, gt_class in zip(gt_boxes,gt_classes):
        ymin,xmin,ymax,xmax=gt_box
        ymin=ymin*img_shape[0]
        ymax=ymax*img_shape[0]
        xmin=xmin*img_shape[1]
        xmax=xmax*img_shape[1]
        box_patch=Rectangle((xmin,ymin),xmax-xmin,ymax-ymin, edgecolor=colormap[gt_class],facecolor='none')
        ax.add_patch(box_patch)
    
    plt.show()

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
data_batch=dataset.take(10)
for i, record in enumerate(data_batch):
    display_instances(record)

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...

# %% [markdown]
# ### Analysis of the class distribution
# In the following we analyse how the classes are distributed within the whole dataset which according to the docs contains 390,000 frames.

# %%
dataset=get_dataset('/home/workspace/data/waymo/training_and_validation/*.tfrecord')
class_distribution=np.zeros(4,dtype=np.uint64)
max_obj=np.zeros(4,dtype=np.uint8)
for i,sample in dataset.enumerate():
    sample_classes=sample['groundtruth_classes'].numpy()
    uniques, counts=np.unique(sample_classes,return_counts=True)
    for unique, count in zip(uniques,counts):
        class_distribution[unique-1]+=count
        if(count>max_obj[unique-1]):
            max_obj[unique-1]=count
    if(i%1000==0):
        print(i.numpy())
    if(i.numpy()==390000): break
print(class_distribution)
print("The maximum number of cars/pedestrians/cyclists in a single picture is "+str(max_obj[0])+"/"+str(max_obj[1])+"/"+str(max_obj[3]))
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/waymo/training_and_validation/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/waymo/training_and_validation/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 97
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-264fed017641> in <module>
#       6     uniques, counts=np.unique(sample_classes,return_counts=True)
#       7     for unique, count in zip(uniques,counts):
# ----> 8         class_distribution[unique-1]+=count
#       9         if(count>max_obj[unique-1]):
#      10             max_obj[unique-1]=count
#
# KeyboardInterrupt:

# %%
labels=['cars','pedestrians','bicycles']
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(labels,class_distribution[[0,1,3]])
plt.show()

# %% [markdown]
# ### Check if frames are sorted by trip IDs

# %%
dataset=get_dataset('/home/workspace/data/waymo/training_and_validation/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord')

first_sample=dataset.take(1)
for temp in first_sample:
    first_id=temp['source_id'].numpy()
    
for i,sample in dataset.enumerate():
    source_id=sample['source_id'].numpy()
    
    index_dot=source_id.find(b'.')
    index_underscore=source_id.find(b'ls_')+2
    #print(source_id[index_underscore+1:index_dot])
    int_result=int(source_id[index_underscore+1:index_dot].decode("utf-8"))
    #print(int_result)
    
    if (source_id==first_id): 
        print(i)
        break
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/waymo/training_and_validation/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/waymo/training_and_validation/segment-10017090168044687777_6380_000_6400_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# tf.Tensor(31, shape=(), dtype=int64)

# %%
f=[]
for (dirpath,dirnames,filenames) in walk('/home/workspace/data/waymo/training_and_validation/'):
    f.extend(filenames)
    break
for file in f:
    data=get_dataset('/home/workspace/data/waymo/training_and_validation/'+file)
    frame=data.take(1)
    for temp in frame
        display_instances(temp)
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/waymo/training_and_validation/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/waymo/training_and_validation/segment-1005081002024129653_5313_150_5333_150_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-c5f0e05da8db> in <module>
#       6     data=get_dataset('/home/workspace/data/waymo/training_and_validation/'+file)
#       7     frame=data.take(1)
# ----> 8     display_instances(frame)
#
# <ipython-input-8-7d9534e742ea> in display_instances(batch)
#       5     """
# ...
